# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/demosike_for_128/
# Out:
# /content/drive/MyDrive/demosike_for_128

# %%
# !pip install torch==1.5.0+cu101 torchvision==0.6.0+cu101 \
  --find-links https://download.pytorch.org/whl/torch_stable.html

# !pip install tensorboard opencv-python etaprogress torchsummary ptflops \
  matplotlib scikit-learn scikit-image

# !pip install colorama
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ERROR: Could not find a version that satisfies the requirement torch==1.5.0+cu101 (from versions: 2.2.0, 2.2.0+cpu, 2.2.0+cpu.cxx11.abi, 2.2.0+cu118, 2.2.0+cu121, 2.2.0+rocm5.6, 2.2.0+rocm5.7, 2.2.1, 2.2.1+cpu, 2.2.1+cpu.cxx11.abi, 2.2.1+cu118, 2.2.1+cu121, 2.2.1+rocm5.6, 2.2.1+rocm5.7, 2.2.2, 2.2.2+cpu, 2.2.2+cpu.cxx11.abi, 2.2.2+cu118, 2.2.2+cu121, 2.2.2+rocm5.6, 2.2.2+rocm5.7, 2.3.0, 2.3.0+cpu, 2.3.0+cpu.cxx11.abi, 2.3.0+cu118, 2.3.0+cu121, 2.3.0+rocm5.7, 2.3.0+rocm6.0, 2.3.1, 2.3.1+cpu, 2.3.1+cpu.cxx11.abi, 2.3.1+cu118, 2.3.1+cu121, 2.3.1+rocm5.7, 2.3.1+rocm6.0, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0)
# ERROR: No matching distribution found for torch==1.5.0+cu101
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for etaprogress: filename=etaprogress-1.1.1-py3-none-any.whl size=15612 sha256=90007781f5cd893200369f3cd72fefedb4a060ff939cc16b1538f179f13e24fb
# ...

# %%
! python main.py -i -ns=0
# Out:
# 2025-08-30 19:46:22.813041: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756583182.845696    1385 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756583182.855699    1385 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1756583182.878939    1385 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# 64*64에 128로 바꾸려면 json고치기

# %%
# %cd /content/drive/MyDrive/psnr/
# Out:
# /content/drive/MyDrive/psnr

# %%
# !python psnrssim.py --original_dir /content/drive/MyDrive/psnr/original_RGB/ --contrast_dir /content/drive/MyDrive/psnr/contrast_RGB/
#original_0001 ~ original_1000 / contrast_0001 ~ contrast_1000 으로 넘버링 필
# Out:
# 총 1개의 이미지 쌍에 대한 비교를 시작합니다.
# Evaluating Images: 100% 1/1 [00:00<00:00, 58.25it/s]
#
# ...
# 최종 결과
# 평균 PSNR: 39.1837
# 평균 SSIM: 0.9853
# ...

# %%
# !python psnrssim.py --original_dir /content/drive/MyDrive/psnr/original_quad/ --contrast_dir /content/drive/MyDrive/psnr/contrast_quad/
#original_0001 ~ original_1000 / contrast_0001 ~ contrast_1000 으로 넘버링 필
# Out:
# 총 1개의 이미지 쌍에 대한 비교를 시작합니다.
# Evaluating Images: 100% 1/1 [00:00<00:00, 77.37it/s]
#
# ...
# 최종 결과
# 평균 PSNR: 39.2535
# 평균 SSIM: 0.9855
# ...
